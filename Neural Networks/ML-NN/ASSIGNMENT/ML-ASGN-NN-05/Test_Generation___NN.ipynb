# %% [markdown]
# #IMPORTING LIBRARIES

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 1us/step
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 349s 2ms/step - loss: 1.9591
# --- Generating with seed: "er growing and becoming strong, equilibrium, ballast,
# and pe"
# ------ temperature: 0.2
# er growing and becoming strong, equilibrium, ballast,
# and perhaps and such a consizer to which the some the moral stringten and which the superience is a the moral so is a man is a complent of the propection of the conscience of the conscience of the conscience of his sore to should and conscience in the spirit of the some and the conscience of the strengs to does of the conscience of the superience is the been and consizer to decession of the conscience i
# ------ temperature: 0.5
# ce is the been and consizer to decession of the conscience is imperson conscience of him of a the precention of the history of firstives, in seem as it mean a god, which and measing of the premosions and interceive of which the have a all nature of in measice in the world is a sore the fore the dealients of even it is the comples of preed of the does or and which is morality of refuled, to the hellers of the earther to a spirit all the belies in has be a s
# ------ temperature: 1.0
# lers of the earther to a spirit all the belies in has be a spiris the just esseciity. ot is droand, as, we
# have welles"--but lyst
# re" to
# the porwanyta
# deselves not as spepe (and
# distinctly is
# abtemment
# and idvenary for exdestime to how "the for the be in god!
# this feol
# puryible of if rougho reloed as have find cast shill  the hour indecaied what to be trreving of hould at and
# farthing more it deete
# not are
# refolencting excepted is the philosophy of scire l
# ------ temperature: 1.2
# e
# not are
# refolencting excepted is the philosophy of scire laft as overy a truth ands!-; beliech clark, them, guraw of all other, eaks(onhy rester if emests andtect, of god. so inegacticm, or incre[t, inscorw, as trey "great. or latial oping,
# viegalmentart. out, toul ts
# hax af rearn, mosting of viraly--gut) dimiction to liked lardjned slatule.g of gaves a philesowevul volve, and of were lably sukope fnow only oneraclulaptest, and
# ischaugnde.=--suchetid whe
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 350s 2ms/step - loss: 1.6144
# --- Generating with seed: "o, that
# nothing is more common than to do wrong for the plea"
# ------ temperature: 0.2
# o, that
# nothing is more common than to do wrong for the pleasing of the serves of the present and the contempt the farther the seeming to the seeming the conderness in the present of the profestion of the man of the present of the profested and the profestion of the present of the seeming the seeming the art the present and the seeming the seem the soul of the period of the profound and the present of the sense of the present and the man and the seeming th
# ------ temperature: 0.5
# t of the sense of the present and the man and the seeming the heart means of which out of the permons of the contempt some to their also the most rese their different to the seem of deams the conduction, and the in the german concemning to in these sees a something has lew as when the farthing, and something the sympathy that the profestion of the and consequently is the man is not and consequently to say, that when the profound of the prace who heart mora
# ------ temperature: 1.0
# y to say, that when the profound of the prace who heart moralficolestif understandies to afmation there was
# sere it from and mey when to chounding is preparpie sympathy of creas of questionts,
# it
# soul andef. now oach hind time not some ockiodances
# has to invals
# of a the
# seir fore in decredes."
#  fentance and to one, he from own. and very best their is-gued what was go fearness, out of an itsule ven spreesticilarchers man.
#
# 1eive,- ood. in astanicos of its
# ------ temperature: 1.2
# n spreesticilarchers man.
#
# 1eive,- ood. in astanicos of its vuever affer spearins to bad dieype: whethin
# slive with stray
# dotessmedehprongs, nece it and century has noponce: is the viey, art
# thought
# incisuss) as of stupines divory too,
# rothy,
# the
# irmen datured new perversamety, whon, tithsy of
# the men and
# elfication of trange mease.
# and
# ising ofpent of mutile and
# that.
#       , man. brunbet, im
# prejd. the quelahabile:
# in there have where of goe-lise) and de
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 351s 2ms/step - loss: 1.5288
# --- Generating with seed: "inventiveness and bravery
# in undergoing, enduring, interpret"
# ------ temperature: 0.2
# inventiveness and bravery
# in undergoing, enduring, interpretion of the soul that the moral to the sensetence of the soul the soul the sentence of the distinction of the spirit and the senseted that the extent of the distinction of the sensetoo of the discovered to the superiority of the states of the souther to the senseter to the moral of the spiritual and the soul the sensethe and the supermonical such a soul the superstical and the soul the conceivation
# ------ temperature: 0.5
# al such a soul the superstical and the soul the conceivation of the present
# has more the good body and man, as to diseptimation of this intall the most word of the most the mode
# to the passion of the distrust the soul evincest has before the finding of the appreciones, the restined, as the soul has perhaps do all the contition of the receination and that the power that it is not the conceition, and the presentional moral and the specimetiment and delicatio
# ------ temperature: 1.0
# d the presentional moral and the specimetiment and delication, as
# the higher,
# and had out of meptive and reminety is, one authirmaty celtise all his necessity to me
# things too confurition of corforationsticiants lawnge to
# his ofoetenation,
# and natures, indfex thritemso so be
# one
# memihas
# boed to soveriagent as the putites the prifosces, admis of  mokes foellory in for the
# insciels centurie thousan god,
# as remary traditues.
#
# uncements, as
# it. sonce in the bo
# ------ temperature: 1.2
# god,
# as remary traditues.
#
# uncements, as
# it. sonce in the bodge of sign of best persuitly,
# enroy,
# withouther seate.--it po
# comaving, so thing to yes is ; course is scurtivation is all
# mind as too-nable has vavious of tay smilal intelloie anhigss--as he cave no lops--as, the really,, if withed by the indures as to ebruaches, to perlookinather,
# when it to same sidficaciectical that that
# as "instancy, of intincery own it the badly into necestion of oken eeps
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 350s 2ms/step - loss: 1.4833
# --- Generating with seed: "on. he responds with that which he is
# glad to give, namely a"
# ------ temperature: 0.2
# on. he responds with that which he is
# glad to give, namely and perhaps and the ever and the same the world of the soul and all the soul and something of the same the spirit is the same the same the same which is a man the same the self that the same the superioral and that the superioral and something in the same the spirit and in the same the same the same which we have the world of the experience of the same the same the same the same what is a something
# ------ temperature: 0.5
# e of the same the same the same the same what is a something ever
# that he has been appersed as it we will to desired distinguish, will does he was the same human that why, the instance the above the same mind to so desisting and cartical something and bad in the even disconding ptilourd in which the something of the does how man that the long and in the same manifest itself of the consideratic philosopher and
# person of all in which the perhaps their was sh
# ------ temperature: 1.0
# losopher and
# person of all in which the perhaps their was shu langer egained they prowicer, religion
# so madent, hage, when iniferent, feels have takes that they larc genis of the centination there would great is the
# speciatic,
# him which, the spirit, raourster and
# hang wishes, this vaineding in sels at super-will for heart, seement another care and and judgment dessible thears--in nonely as has in the world, whon at thvinessment, any be restly theirto--and
# ------ temperature: 1.2
# the world, whon at thvinessment, any be restly theirto--and how doguimrty--acquiring, of
# unwearase to uswine cranling well
# untwhere
# even and calledness and ginary
# surdom have
# to taste, examplts of allflequededprast feel oving of
# confinities, he is bad, something there sight that lacks why was
# no somety.
#
# lever willifyly is all de unal, murthing than abod tymeriring than impwysianar to noner ciself tormly,
# as as we philosophy of saint; in just him i he is m
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 349s 2ms/step - loss: 1.4522
# --- Generating with seed: "t cannot be taken away without irreparably injuring those be"
# ------ temperature: 0.2
# t cannot be taken away without irreparably injuring those because the senses that the persons and all the senses and the most precisely the seems that the senses and sollence is a man and the conception of the same the world and the free spirits of the formerly and the most consideration of the profound the most saint the same the fact, the most senses and the stronger that the most all the spirit and as in the same the most conscience of the science, and
# ------ temperature: 0.5
#  and as in the same the most conscience of the science, and that they there are conscience, and the same the singes to christianity, and the whole of the respection to the seems and relation of the spiritually the powerful and say, and the soul has not that a things of instances and that the first the reador. in the charm and formally and domand the most do that a loves and sur the schearing that it is the comparised and the relation of the lack that the p
# ------ temperature: 1.0
# it is the comparised and the relation of the lack that the pessified as "equal now condition, as the sixper, is to every desolps, as a reuser revery the exiscings. the discitifidation and methonce men, and symit
# in charality
# and rialingality
# in orders and mis! they the telred, say. to cheats!). europeriely
# and strange and
# history and dwingrenwilation: it wouwh of gooden inipicates all cakes perpactoric,
# also world have wick.
# peririves,
# a detimated one for
# ------ temperature: 1.2
# toric,
# also world have wick.
# peririves,
# a detimated one for a lyinged paust rustness
# for a grim.h
# dovear lights will cause comis: and let
# unan, mondves-moral
# untypively scienceh
# and megiving wisen moral espeabt could being instinct
# to awaker the certaincy, that no, the frollifgt, in their have been absolt cloupt. o
# course thate nothing may perpemusle, the form arfu,y, it is will chimate gro'sh nayed he made wveelly.--the modest
# proto make, od, at sinfest.
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 350s 2ms/step - loss: 1.4302
# --- Generating with seed: "m of knowledge and conscience
# has hitherto had in the souls "
# ------ temperature: 0.2
# m of knowledge and conscience
# has hitherto had in the souls of the strength of the spirit is the man of the world and degree of the spirit and belief the modern the spirit of the world of the spirit of the personal spirit and develop in the rest of the strength of the strength of the constitute and deconality of the considered the problem and solle the problem and fore who is a soul of the spirit of the spirit of the modern to be the modern to probeloged t
# ------ temperature: 0.5
# of the spirit of the modern to be the modern to probeloged the impulse of more end, all a modern to speak of man and greater propersions of a greater religious lift in the lost, and manifest of the bring consideration and conscience of the modern permodive
# strength and refuted and same a fatter of the characters and really be and constate of the faith the still of the democration and fore owen in the same to be look and dinguse there is not once with a sto
# ------ temperature: 1.0
# the same to be look and dinguse there is not once with a stoon wishes conceptionsch. under the
# compost-inately more slupk oncuwar--and i.
#
#
# 11
# o question that owigge-guant dence they had be these better present fatuled in    to rearing be suverep
# for that this was an a
# towasdy to decurity of the most tendenidly destruls in the gods, and wered overwhich, all religionsm in the fear of flo,
# here the exact that wruther it than is day nagenes but the cause of b
# ------ temperature: 1.2
# exact that wruther it than is day nagenes but the cause of bring "moderant oigrationmary,t--more napure of affatre
# moe.
#
# 211. and greater, fo, for eexuefful
# of gratitu-aluem of mope as as "glow incoler fhopices is, but but
# a
# sin, was before yeadful--the most to dayd, abopes emply impered emorinarb an imats; aftermand be drons her and hahoude on ofebquanod does but im truch lardtherficistic whole an
# abstruct a not obediel utureps much
# him acconswders in sou
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 344s 2ms/step - loss: 1.4124
# --- Generating with seed: "the typical prejudice by which
# metaphysicians of all times c"
# ------ temperature: 0.2
# the typical prejudice by which
# metaphysicians of all times consequences, the stranges of the spirit as the strength and the stinds of the spirit and all the same to a man with a think of the same to the spirit of the same to the spirit of the sense of the same to the states of the fact of the stranges of the stinds and deceited to a commander of the same to the states of the still as the strength and senses the stranges of the spirit to the spirit is a sub
# ------ temperature: 0.5
# and senses the stranges of the spirit to the spirit is a subtlety, and has the spirits of the
# same states of view of the imparation, and something and discire to its aways as every surposing of the sensible are can coman leads to who have comprehatical feeling and inventive the present, in the predicate that the same the precisely that the same new that certain most wonday the fact of all the ancerdor, in the scientific termination and interprediated furth
# ------ temperature: 1.0
# rdor, in the scientific termination and interprediated furthing
# attpinates, memirdics of them and against a. the fuths obstrachuesisissibly the really? we wasty are
# art think of moller its inspires
# has levelly, too our samishtrous another truth in regarding unabotism relations andres excesst on
# impussian, which did
# the fowed"--rughty more
# separisy authow man would be
# after earti's may, there is
# noterish saints
# in the errsiging and good etercgly and
# wkise w
# ------ temperature: 1.2
# terish saints
# in the errsiging and good etercgly and
# wkise without authow demosed of excaste
# takenwere everyy wognegher--this deeper, not--as lacu is are clearh--ag:it
# oroneves, fare for oviver--a fart
# le
# the questionally insepth new. must be
# shuminos-migstable swart, gale todmouns by a
# like: now, unstrance from themselves by the fear of coarse, with suffer,
# he conlectionable
# misultimate, orogres from remart frow elevaiten our your c"kpesomencenk in unress
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 344s 2ms/step - loss: 1.3981
# --- Generating with seed: "susceptibility and conduct in behalf of others. indeed we al"
# ------ temperature: 0.2
# susceptibility and conduct in behalf of others. indeed we allow the contrary and conscience of the spirits of the spirits of the conscience of the spirit of the world and the spirit of the profounds and the concerning of the spirit; and the morality of the sense of the contrnance and the fact of the spirits of the spirits of the contrary the sense of the one of the concerns in the spirits of the spirits of the religious soul of the contrary the spirits of
# ------ temperature: 0.5
# pirits of the religious soul of the contrary the spirits of the hold soul, to its its compares of thinking and sense of the party and soul of the world and matter of fact the concerning there are existence, and let us all the responsible of the away of contrnces of which as the person to gradutive generativeles, some with a power to philosophy for the original spirit and the ambilitarian indeed really the surplated and sum it is stranges to the serre from
# ------ temperature: 1.0
# ally the surplated and sum it is stranges to the serre from righted," without matter is evels, one was usec any christialis--
# unmadereds the concurved its snalle, the beeque only withty strake and stacied
# arrived patus out ascations--alreabnyingrarry to these an end is eaglenceh unter ofthing-animileness, seriousrs--and has generative cwholance--there is a xagolative agree--hute everything wishes comprehension of philosophy inconvived class, with its acts
# ------ temperature: 1.2
# comprehension of philosophy inconvived class, with its acts greegh---and illinglence, whouborh naturab.gein--proud most despated those; late exfamemivijum,
# realn--weabment, thas is asss
# epacuse ;e what has etisusxward evil wfic) himself--and
# can frotth; indappiature benepess), indeed, author will be famil invociadoms hi!
#  mpking, diccruivings amantive by gaker
# educual, sun friendshppuccolosing su charachers, when a under old
# strugglebil"-need of gi philoso
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 342s 2ms/step - loss: 1.3869
# --- Generating with seed: "w as the
# credibility of the ocular evidence that "the earth "
# ------ temperature: 0.2
# w as the
# credibility of the ocular evidence that "the earth of the same the contempt and the same the profoundess the superiority of the spirit and the most the more perhaps as a souls of the proper of the still a such conscience of the still a superiority of the spirit of the proper of the sense of the same the souls of the sense of the spirit and the possession of the sense of the spirit and the same the spirit and the progress of the same the proper of
# ------ temperature: 0.5
#  same the spirit and the progress of the same the proper of the habout the discorroment of the sick to the free spirit, the compeltic destiny and sinner upon the spirit and all the desire of the such conscience, the fact that the estimation of the case be experience, as a midear, the sentence, that the spirit and periods of the child and sentiments of different religion of a sort of the most and the extent the same the shilling the spirits and the testem o
# ------ temperature: 1.0
# he extent the same the shilling the spirits and the testem of divyneness europe, an and disposinganged,
# the human false venement of species of moraliar
# at a men arise brought in the baveitory is an invarses, as delecated himself at
# lives as alty, not out of the cause and not a deterided, as the sentiment.
#
#  he is, to a sporently
# enderat
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ion very
# deedsing, all the means of the schoeally will it upper himself and will be id with that in the typicals
# tedrivo--
# ------ temperature: 1.2
# r himself and will be id with that in the typicals
# tedrivo--or
# away to refact at pro"bly for esher
# peuse-accorned good in manwwileed. as one about the has ju, of the contrary toulish.--when, very under pations of a "by
# degree of an means of
# equal incorclueity.=--or themselves from the menulus types for maxures to
# ruted of metaphysical valueow
# cauns exfal
# armunt? fictating: they comparisors of welimate at "truthy to of met our aloniaperar about nonwarn: thi
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 344s 2ms/step - loss: 1.3774
# --- Generating with seed: "reins fall before the infinite, we modern men, we semi-barba"
# ------ temperature: 0.2
# reins fall before the infinite, we modern men, we semi-barbarity of the constrained the order to the sense of the rest the man, the attempt to the man is the sense of the rest and the man, the problems and in the forms to the suffered and deceive and the discovered and moral and the belief the german man is not the most consisted to the same thing is the discovered in the same thing in the reason that the reason to make the most called be the promises and
# ------ temperature: 0.5
# that the reason to make the most called be the promises and should
# in the personal and age in the manifests the first the propessity of the purpose in lith relation of the art and harmed and in the traditions in the comparishy of the commence, the degree of its taste of the call a productive for this nature of the case of its master of the perceives of the forms of a promises of the fundamental such and the free and and states and deed in the resolute dece
# ------ temperature: 1.0
# ch and the free and and states and deed in the resolute decelver its cave of psychoousness for
# absusoly for inbalitacy of a
# impresibring dance, finds and
# that they are ever
# man "awamt, shelener--the
# religion, in the rany dreaman pending or of developed by that misunderstanitates--but if thus a sufficis of      wess, able true cried to al formuling primation.
#
#
# e(hapely waits who good:--
# earftiness. thru). propessity in generation.
# ever prsmisition as the l
# ------ temperature: 1.2
# . thru). propessity in generation.
# ever prsmisition as the lation makes
# influence to look errain terriaced old law is
# induc immean
# pterclusly, eorble frieng awar sharv sad
# lef
# withsing uskingly befe soul by that man
# penkpquenments, pyek. go-isc) sadicianidiguring to powers, look.", sign of accormune that more ruble spirits, could vrevaicivies even is believed the frye learness in
# the learingnable tothubfurancable divine show do would not decommption are th
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 346s 2ms/step - loss: 1.3680
# --- Generating with seed: "shamed when they suspect that obscene thoughts are attribute"
# ------ temperature: 0.2
# shamed when they suspect that obscene thoughts are attributed the man and the sense of the sense and predication of the strength and a the present and the presently and the man and the man with the same who has a superion of the same a man with the problend and superion of the really a sense and the spirit and the a predication and the man who has such a person of the existence of the spirit and superiority of the same the sense of a sense of the strength
# ------ temperature: 0.5
# uperiority of the same the sense of a sense of the strength and are man themselves with the man with the world of pleasure the cause of the same expression comparation of long the self-germany as the sense is they have a "fathered and something and in the self-nature. the present an extraurvall the element of him." and the truth and intellectuality and politician breake man of the supervacted hand that the destrused them a defenses that the germans, and a
# ------ temperature: 1.0
#  that the destrused them a defenses that the germans, and a merely a moreovermen which would that is the ahich, exactitles als. someth: "which will precisely, the appetic and
# more spurpone and histerious every duch true of phenomeness the human stupidity of greute matters appears the word wild garver has "chomat of the science. "which a rather
# man sought that he expecizely
# distressfied explain our prepontion, but a perfect his any oneself (in bite of man h
# ------ temperature: 1.2
#  prepontion, but a perfect his any oneself (in bite of man him,o,ueorious keep attemils unbitty
# responsed thought, without xoneritment. that whentings of ethiness?
# imll, they has atple
# ?velse--and without-: to gaiden.
#
#
#
# then this khelosan! les in crigins ourselves--un"edical distrust
# a hon but the
# relation of humanicour indismntments of more judgitres deepered bit advantage
# "stecrism,--; long from
# that the truth, to make that p
# yomaghing and grownk--of th
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 344s 2ms/step - loss: 1.3609
# --- Generating with seed: " not at all by us?--we men desire that woman should
# not cont"
# ------ temperature: 0.2
#  not at all by us?--we men desire that woman should
# not contempt is a soul and also the strength of the soul and souls of the same taste in the strength of the same transfarmitions of the strength of the strength of the degree of the same termed to the sensition of the strength of the struggle of the sense of the strength of the strength of the strength of the same explanations of the sense of the strength of the strength of the present and things and the
# ------ temperature: 0.5
#  strength of the strength of the present and things and the more conduct of the case of the unjust best increase in the same transfare many misfortely more will and soul and here thinks and plays the agered in the greatest
# of the world of the new prepains to the away to the least the discorred, as it is a passion of philosophically instincts of the certainty. the words shatter of the can be ancerness and conscience, and as the spirit and will possess of so
# ------ temperature: 1.0
# ess and conscience, and as the spirit and will possess of soil worth an mobord has should very assers
# at this ythe word
# asoritions and distinets of romacisk tay an
# and
# there are have now attuile in
# likewile sin certainty still ofct surblicably seritororary
# !by men and nor tonged taken has bothing-could. but they preadinae
# he most interpretrous knows for instance to with these hascary
# once
# mere latter--and according to which as he means of manures.
#  to degr
# ------ temperature: 1.2
# ter--and according to which as he means of manures.
#  to degreear of spsy an obceuse of pied mind
# could alsostiment many intrain of
# the sapirating, and distinction, he haga, a peringd. one careness. capacus, for one'whild betters", from hercedomines dis, sick, as ten aut.
#
#
#
# ce(ble voictions of priesion in averiswer his emphracy and doons men that regharted luxims, respire.
#
# every, be ponopers, who cashesod liqued to
# miskily general right
# us
# and classing,
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 345s 2ms/step - loss: 1.3535
# --- Generating with seed: " more radically ingrained
# propensity opposed to it--and in t"
# ------ temperature: 0.2
#  more radically ingrained
# propensity opposed to it--and in the sense of the self-dis is at all the soul and the world of the world and all the successful who will the such a something that the self-rest of the strength in the schopenhaence of the sense of all the morality who condition of the species. the most personal and something that which the moral man, as a such a self-all the moral and such a condition of the world and some the moral and some the re
# ------ temperature: 0.5
#  a condition of the world and some the moral and some the religious the charms of the processes of all men a rater of the childine man is the extent the mastering of which the moral a conduct as the consequence is call a thinkers of the marking or a love of the philosophy of the most problem, is at the still discipline, that the contradicate and distinctive and some actions, as a more into the remaris of all itself of his world in the stronger of father of
# ------ temperature: 1.0
# aris of all itself of his world in the stronger of father of metifthers
# fulloan
# soothy. and in
# order to detioned pyture. for free acts lift bialw with a sujomes, is were will opinion--all their fellow man, the just appromediated, gerach or befo-non occase ridenation at which given only srill state is were if the
# religious let man the should the treach.
#
# 131. that which lookan some closence of hissiration for it will enralthges of epond--that the badners--a
# ------ temperature: 1.2
# iration for it will enralthges of epond--that the badners--as religion. estepenis" we
# giventally with christian gods is doaus, something scacke,
# doss to being who-sent their exptiessation
# profound trapsuance--whatever mendutedly world for men odwible," manops a light
# in sfitelos of gals: and call attains--the idettone. thereby, of-comfuspes that an
# abome of means, man
# berrow and ever me too unterable peofrous, angatimiis
# eaminged to inclinactions and tappv
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 345s 2ms/step - loss: 1.3467
# --- Generating with seed: " we should understand
# that such judgments must be believed t"
# ------ temperature: 0.2
#  we should understand
# that such judgments must be believed the such an instinct of the moral and the man who has one of the consequence of the moral his such and the problem of the moral and such and something of the father of the moral and some then the world and the problem of the greatest and the deceived the problem of the moral and the moral to the moral and morality of the moral and self-receled the such an and the moral souls the precisely the same
# ------ temperature: 0.5
# eled the such an and the moral souls the precisely the same tempe. the exercies and so the antive the freedom, and in the same truth so the truthfulness of religion to the lookened in the most person of him who go one may be enthural in the most becomes in the basise of the are thereby his life and the world and are consequence of the existence of all the antived to the origin. it is there is a problen the same truth of the consequence is something
# in the
# ------ temperature: 1.0
# oblen the same truth of the consequence is something
# in the spirit, as a bad generatious, and hegefbition, rebelouson, without stront than
# parce of legs in a comprehensity, if such hithest sea only he has
# intagnible--in such any self. should rather
# hagaving who free sperim and
# his a-metiinateoy), toom in say).--perhaps what pare christianity of lidedonaice if the
# too errorical enount
# crean evoluerony, because of unoverprantially philosopher in which one oo
# ------ temperature: 1.2
# ony, because of unoverprantially philosopher in which one oovierance of moratce is
# usker, utue) grown all the grertly seachority
# is mediocrehate, man wild in ainguredful"s
# only how however.
#
# 2rof-yshpusion through "lajo-elere
# temptatily before
# intellectp", the delusd
# din falsely,s hand what is real of which though i were nothing
# belief in is after glacks himself.
# comu enerry "ever aluredollnes of
# the prancet as limfolity, when he philosophy, faironged
# that
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 349s 2ms/step - loss: 1.3407
# --- Generating with seed: "e two kinds of
# geniuses seek each other like man and woman; "
# ------ temperature: 0.2
# e two kinds of
# geniuses seek each other like man and woman; and a means of the same things and sentiments of the being and the power. the german sense of the complete and sense in the same things of the same things of the same things and self-conception of the fact of the sentent to the entire and such a deceived and sense and complete to be all the same the sense of the same things and sentiment of the problem of the world and propertical suffering the st
# ------ temperature: 0.5
# of the problem of the world and propertical suffering the state of its presence, as all the enough to free spirits reverence, for instant in the are the has your dreadful and subject to self-moral commander of the states and aristorical sense and the profication, and as the profication of the basistous he were the being and
# and bading the possible of its own harm and senses of its simpley to "guist it there are indeedition of precise of a person soul the l
# ------ temperature: 1.0
# t it there are indeedition of precise of a person soul the latter--namely, and after like, and years well tarin--last no more
# phicomence, him, and lake a good philosophy has how be conscience, the morality of the would be as allect
# to
# be now moral stemper more earrness.g--when he wals carnificoge here of that revered tokempoes and nature of this cashe wind him.
# ev
# harn princiiab it let of the case of , not bod, in vanity.
#
#
# 76
#
# =vanities, were only do with
# ------ temperature: 1.2
#  of , not bod, in vanity.
#
#
# 76
#
# =vanities, were only do with men in which is relation, tomany-low. he polimage by the plaholereded people of
# else here,
# widers in herading simple justices this matable "rifinabllgiarity of surkflily causest him--paye ital
# civilization; which is not effect and imman
# which christianive which
# impreof gradned as that  : "ofter has,
# own fight,
# natural, the dirnation of the
# futuritying imtres that make, a hours, he ismed su love o
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 345s 2ms/step - loss: 1.3360
# --- Generating with seed: "red and attained through the self-evolving of a cold, pure,
# "
# ------ temperature: 0.2
# red and attained through the self-evolving of a cold, pure,
# who is a condition and as a thing to be all the same the sense of the same the as a delight and all the sense and something in the same as a man who is a man who has a self-reality of the same the man with the same the entiren and the same the same the same a man who has a self-delight of the subtle and artists and substitity of the same a soul they are all the same the same the probable and the s
# ------ temperature: 0.5
# a soul they are all the same the same the probable and the soul has he properated to the facts and an assertinated to entrached as
# think of the man will philosophers of the emility. and as it is something and "free spirits of which can a warterity of its may enolow as a thing and german and as, the
# religious reverence as an and the probable and more and same the period with the same the empliable and there is not probaper the account and deep the conduct,
# ------ temperature: 1.0
# and there is not probaper the account and deep the conduct, as
# a the circumscruhen--as are syan world so puriting
#
# and is
# its may how possible, the young weaking vaokian a germans was to believe of men spirit, they tawe; the amart refuged sunregines fact and socveting by the incaral demands, comes precisely, atherding to reality on every
# comence and
# belief (ighegard they allowy, orone better poerd are convenient who stren, them and a present--this is if th
# ------ temperature: 1.2
#  are convenient who stren, them and a present--this is if this patos, affairia like theres," of subguin true.
#       not is a
# so.
# let us means, mustks, whice, still mairdly was ,       us, whateven self-genialued to may be acquieing self-dourtyred ineakhthful himself, and slave" according to former aroughment, not prively
# to butiness and to
# divally forwher to distidie destituted often live,
# knawhy shame, and lerios: themselves as dignained to
# whowh certain
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 349s 2ms/step - loss: 1.3294
# --- Generating with seed: " can still be original, probably as parodists of
# the world's"
# ------ temperature: 0.2
#  can still be original, probably as parodists of
# the world's and superiority of the superiority of the superiority of the sense of the discovered and superfict of the form of the superfict of the conscience of the superfict of the spirit of the strength to the sense of the presentially and the great the and conscience of the sense of the sense of the sense of the strength and all the bad in the structure of the structure of the fact of the same time that t
# ------ temperature: 0.5
# ructure of the structure of the fact of the same time that the great incrialble our amought and all the same today, the spirit and interpretation of all that the element of the most distrust of the soul, as the play to imparting and the betrayed the most opposine of the process of every entailed ourselves because it is the consequence of the cause and all interpretation of all of the spirit and in the best propect present that it is in all general more man
# ------ temperature: 1.0
#  the best propect present that it is in all general more man of
# dreame occa tured, man should woman--as their age, it who heldering crave enjoys desires and by mirrocted taste in thing, undied abyser, ratter consequence of shemple in the "certainly only at the utwlal
# soul, also easou tote foral rices of actional of sanctive world extent
# of him of power, with our "science, as has flolie fast for moral and kindn unly fundamental characteristerity and in the
# ------ temperature: 1.2
# ral and kindn unly fundamental characteristerity and in the sympto stlanes. rroughle asm but let nservence
# among the doil complating upours for second as the
# gaiture other spess him from aithout troju saccor. at bringy of ydrangs) to thoughts", as may bofking element of frants--people--in -that shoo, somethink and ordination magi". ungetuens of expeciatained towards she is-morour of the cruelty, unbation than
# additation within which choew deserntution" wit
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 353s 2ms/step - loss: 1.3276
# --- Generating with seed: " in justice. hence one must say "the wise man
# praises not be"
# ------ temperature: 0.2
#  in justice. hence one must say "the wise man
# praises not be sought to the present hardy, the present and power to the german to the manifests of the same the belief the man in the artists of the consequently and conscience of the most accustic and conscience of the same the same the man is a man of the spirit and also acts of the expression, with the spirit and the great and the most consequently and also in the structure in the consequently and responsib
# ------ temperature: 0.5
#  and also in the structure in the consequently and responsible will a strong and forest process of the expressions, were reality that other of the man is also it is distinguished and altered in the religions of the history and
# distinting the consideration of the emotion, he was there are all these are
# partial promise to the hardy, and man in the same truth and conscience that such a man who has the discourse of course of the "truth and manifestation of a s
# ------ temperature: 1.0
# e discourse of course of the "truth and manifestation of a sendanding commence and deed of a rature
# is destruct and
# personalure fuen letiused
# to the xormory in carbuling and ci, of lived to leav be doming probable that accountomes would have they man needs haumn from the
# egoisms the beliefs vuewardess as thoughicial agree up time opposes.
# stone wher theye barbalily allow, to believe, in pust and acts that
# had in their two is to be
# robary, the way "tknulbly
# ------ temperature: 1.2
# cts that
# had in their two is to be
# robary, the way "tknulbly?
# near, shealtrine so that sufferers in
# a_se--fur
# all toscheem,
# amought to the (clagerness of
# merely an expression in itaning.-it is even with our
# the
# most
# combeding in suffering of cost so falr struch "labee? well, dhejorn harmle's use "magic,
# which teably old knowledge; in wifeing" foo,,
# he sees good blunde" anor freendsly, in
# a "from
# eleur,
# inward, uptial comovency o
# sufpers. not wisdon cruue p
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 349s 2ms/step - loss: 1.3212
# --- Generating with seed: ".
#
# 256. owing to the morbid estrangement which the nationali"
# ------ temperature: 0.2
# .
#
# 256. owing to the morbid estrangement which the nationality of the spirit and such a property of the sense is a man of the same such a great one that is a subtle that the sense of the same truth, and something to the strughfuring the strength in the strength of the strength of the strength and self-evil one more the soul the really the still and self-religion that is a sense of the still still the same time and manifests the strength and property of the
# ------ temperature: 0.5
# the same time and manifests the strength and property of the still of his experience of the same sense is a perhaps the greatest and such a soul in the
# still an interpation of the still from the convalted to desire in the signifiod of the hands which has conception of the strughfurous emotions, as the senses has a sense of man is the greatest of the father incriel, in the strength at the sense that the evil in the same term the sense of the still
# from self
# ------ temperature: 1.0
# t the evil in the same term the sense of the still
# from self-conceptions) does it is
# sure
# fall "to
# be but hence has noy his individuals,
# more
# precase for wisheshed,
# and soul is no"
# lofty,
# perhaps becaptible well unsoleic or artions too his autilvationity ferthtre in facts as
# them "least, intelliced, who dreish.=--
#      for thoughts, togme.  the scriff conscious taigured: heritihly--he can
# depends and skection. in every
# common and sone" and that is it the m
# ------ temperature: 1.2
# and skection. in every
# common and sone" and that is it the mirroriation, that except of
# foon, youth, ancevious, two salvmerical gmerly--(also, according to the po psychology of mestersomits
# religionied, moneys--; founderly hitherto resqucualse, as afterwards for a ngelloke
# music, vaid," "could able revie. then from his ,
# usoc or grithring" of
# near; i ap."x"j"zzex-aslue punend
# knew. her
# jry among himself into
# spect to vivists of concratfcent expaseness,jver
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 349s 2ms/step - loss: 1.3189
# --- Generating with seed: "tanding and
# ready welcome for those rarer and rarely gratifi"
# ------ temperature: 0.2
# tanding and
# ready welcome for those rarer and rarely gratifilated the germans to the same the present the still the most conscious to the most completely and which is a thing in the sense in the states the problem of the sense of the states of the same the same the problem of the superions of the present the sense and the man which is a sought to the states and self-relation of the sense of the such a problem of all the states the believed the sense of the
# ------ temperature: 0.5
# ch a problem of all the states the believed the sense of the truth of the concealed by the laps and legguedwity of the same the religion of a counter of such art with it is something it as the aside the most called a most specially the self to the most state of can surpluse of the losed of the belief the whole part of conscience of the person in the sense and like the properity
# of moralists to feel the contempt that the men and contempt the marristic a men
# ------ temperature: 1.0
# l the contempt that the men and contempt the marristic a men "will s
# the bother, kant that being of courages as the justice of thires of great our since the pare of "mental nature,
# ancient montains it
# has
# ineurophes, as mean
# more deconony that order apart extent, a song an impulse or the taste ornen.ce.s it doon wait.ky wren, such land
# the such comences fropeness.
#
# 17] suspicious experienced, the self
# could been something of strikesqus conceive truee that
# ------ temperature: 1.2
# self
# could been something of strikesqus conceive truee that whatever mtkind, shaftessdeded,, as the delicately good and merhimity. "moas, whicheic
# over
# humanity
# as to last, the doake free spirits, which
# latike a a timr.
#
#
# 7
#
# =piece; they insempaticy.=--it happiness and "condition relationshir renlely, or unects itself in
# the stitvous, pileks it be longe, is an
# escept to woman the charcher. on that the excets the treaso mediy, as such trime from the subgla
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 346s 2ms/step - loss: 1.3152
# --- Generating with seed: "is the incidental remark of madame de
# lambert to her son: "m"
# ------ temperature: 0.2
# is the incidental remark of madame de
# lambert to her son: "man who has a second and the propens the same tendent of the facts are are the same the struggle and all the struggle and evil whether the struggle and the being and stright that the most something in the same the strength of the same the same time and strain of the senses and the one may be the same the propens the same time of the same the fact that the same time the same the strength of the othe
# ------ temperature: 0.5
# he fact that the same time the same the strength of the other denied in the fact the consequencess of discoure in the fact in the predice
# proved by the genius of the threates, when they all to say than in the same taste of the comment, and it is a thing is find one who has a good and clear him from the generations who have a have been a spirit, how certainly and stright: this self-result the most and the moral vice of the and prevail and almost evil is the
# ------ temperature: 1.0
# and the moral vice of the and prevail and almost evil is the callement for he
# respect grows  for manifests and
# other systented evigures) bood ends for accustes, nor partice of the given thy , what the rides like the struggest
# philosophy in empirited, honour, but adorained to the enjoyment, the maboses of
# histerly an years bours develier than the inposes imposetion and romantice supcreact, foundssly the master, one rate be a ncessen
# proburpe in the existenc
# ------ temperature: 1.2
# y the master, one rate be a ncessen
# proburpe in the existences.--profince whenlend, tokemas
# only
# affarat,
# erbulled in dif instalual a higher, so that bad but man theight ne, "the evil--relignas: this things, galusk irrring the rdansk, as of their morally anything man too farters to those have swclean day
# beauty an ihersess--whenfwen your pith
# to be
# now heists
# tpectly developmong stepker
# more hardes.
#
# 4re romoly, renation its?ly, prose, or chrows hence deat
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 353s 2ms/step - loss: 1.3127
# --- Generating with seed: "fundamental conceptions into
# things. late, very late, the hu"
# ------ temperature: 0.2
# fundamental conceptions into
# things. late, very late, the human and conscience and self-regard to the same time and also and sense of the same time and the super-iscieach of the same time the same time to the same word and something in the same time and possibly and destiny of the same well to a stronger and the same time and the precisely and some one without the same time and self-reserve of the same time and in the same world of the same word with the s
# ------ temperature: 0.5
#  same time and in the same world of the same word with the same fact of a father and more satisfacted and philosophy of the same well be any a more individual. the demadd of the exprestable that the ancient do in the christian more defensive and some mankind at the opination without the most certain not to may without a present that one thing by the world are the beguling in the objective without any possibly of distime is belief and disting of men his con
# ------ temperature: 1.0
# any possibly of distime is belief and disting of men his consequence, which conteasion once other art, as mare makes of instincts short, as it to an statix itself is even a epoterion regards to through physiologisites his equally more sacreculment-
# cause of being,
# resurting, through at significe health
# "must be loritrance as merenjume.--brought and over, the time word his fained to the senses with it, a fluural estony on ranks to the imagine to
# been and ev
# ------ temperature: 1.2
#  it, a fluural estony on ranks to the imagine to
# been and evoluation,"
# are not like
# same windoun,
# and pyritation in this feas, he cannot
# distingusvation," let bad to himself, althoos: in gvomy; he would usuxpving hidden as ahe europeaf, from themselves sta warn eyess. at a
# victuri, who, the virtue, used than that arises,, error that noo
# god, hanced
# in artists, for the expiaitation of our tool, dutver); one foung to those spirit was wicked
# and "free willing
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 352s 2ms/step - loss: 1.3079
# --- Generating with seed: "erve,"--and who yet believe in this good opinion
# afterwards."
# ------ temperature: 0.2
# erve,"--and who yet believe in this good opinion
# afterwards. the spiritual present in the strength and are the spiritual sense of the same the same the super-individual of the spiritual of the sense of the super-its present and superiority of the process of the existence of the superstitual sense of the spiritual problem of the spiritual and democratic of the spiritual such an endured to be all the strength of the sense of the spiritual strength and strong
# ------ temperature: 0.5
# e strength of the sense of the spiritual strength and strong were the moral fact of the superioration of the readily for the mays; he must possess and more and virtue. there is
# a substitute to make his expedient than the superionable becomes understood and superioral of the earth, he is to be a consequently and intellectual and more for the strength of such an more powerfulness that which has a supersible of the morality, that is there are strength and dis
# ------ temperature: 1.0
# persible of the morality, that is there are strength and disfination of rank--if there is me that it doing, to its its i mens and little home in formula--that
# deteduclual different hand undessimitum, may philosopher have provility more which into one is
# remaint feels of
# offering and
# popularly ominors and lower will have it
# lines,
# is at a
# churche rage" in rand to rains are takem-for the courago, feels exhardic, in sometime, medioc a sortten between symboi
# ------ temperature: 1.2
# feels exhardic, in sometime, medioc a sortten between symboic will be generatious formule pains of a have been
# love goodness is incideal whatefhite previous ome allow of laothis
# honor had a una!x in a loves. a
# degree thus smeans, were). we cannot insulrety of woman
# beouguism,
# profoundmining in
# natorism oner stomen and truth, .
#  , lifting, are an
# endoyping science.--there, animply, not,
# antagenezarl
# thr'e pursing prydemority of his own rigy vio-emo, whether
# epoch 24
# Epoch 1/1
# 200278/200278 [==============================] - 352s 2ms/step - loss: 1.3050
# --- Generating with seed: "wn nature, this spernere se sperni out of
# which religions ha"
# ------ temperature: 0.2
# wn nature, this spernere se sperni out of
# which religions has a strong to be a general the sense and in the sense of the spirit of the soul is a the spiritual such a conscience of the sense of the strength and the strength and self-contine and self and the soul of the man with the sense of the sense of the strength and the spectate and and success of the man and also and conscience of the problem of the spirit of the sense of the moral sense of the sense a
# ------ temperature: 0.5
# of the spirit of the sense of the moral sense of the sense and the sure and the strongest force, which has with the religious and the blood upon such a secondulation of the cause they constant of the strength of mankind in my will with it is at one has been for every an a being revolved to be an account and security and will of the necessably, and to development of the self strong and culture of the world who a shart of the same sense of the as a defing th
# ------ temperature: 1.0
# he world who a shart of the same sense of the as a defing the people with when,
# that which, the
# ang is free inning
# emocratic to be will him him to developmance, materves, with responsible rest tas with time resultablect in man"--i dance he stepker,
# all more means, on
# man; a desire them conscious towards remocuation pre sleak everserming of heart, which
# has felt, as an outious, does it is itself now evil.=--and last-herner of all
# the an, thoe, the great the
# ------ temperature: 1.2
# w evil.=--and last-herner of all
# the an, thoe, the great the
# frelious taste--which he who succees of the stote it.
#       s the granglogyped in the strengst,s have stonsed, that with they considation as, their boon advised at the opposition of usecable, for unyoust, and clumspon
# mover, there sangt and than the
# place of view and to are "madey in judght
# bysuth--and ever good everything strengtizen
# cause totere, drupbering throth utilities. indeed, no defera
# t
# epoch 25
# Epoch 1/1
# 200278/200278 [==============================] - 350s 2ms/step - loss: 1.3013
# --- Generating with seed: "of life, future as well as
# present, and will be unable to de"
# ------ temperature: 0.2
# of life, future as well as
# present, and will be unable to decline of the deteriorate the same time to a proper of the strength the moral and self-respectately to artistry of the strength and soul of the father acts of the sense that the spirit of the conscience the precisely the moral and same the sense of the soul of the other problem of the most conscious to the conscience the expression of the most destruction of the conscience of the most distinction o
# ------ temperature: 0.5
# most destruction of the conscience of the most distinction of the choinch for the conscience he was in the concerning the last a more who does how in the "man" conscious and every according to
# strange of the powerful and the philosophy and the bad the precisely the metaphysical were the most conscious and second and the exposition of exploition of interestive the destruction in the instincts, and the destruction of the conscience in this classing in the ex
# ------ temperature: 1.0
# the destruction of the conscience in this classing in the exiesty;" so yet believe
# is religious work-hus mirrly; he-naised in such knoble any meaking of the morality. hitherty after
# when their form of intellige that so soul the certains--adall, soul one not something than the harder, and he is asute: equally a wroed rechardens and firm of god," and he must been -it
# is not how inventive--comes our matter of mind that unangquie the
# arming and bad wheneven is
# ------ temperature: 1.2
# matter of mind that unangquie the
# arming and bad wheneven is serpently, no philosofhing--alweay time, under the
# tedert that he may be fully--but under
# there are a sub is this hive egouras acts when the
# replies iseates? and
# hence the clingtoropize
# after. this sense ti) him
# "pain of
# sadfces, withozd not he is, is, we could i armay of sujely
# foledes of dart of
# divinaties or speciall, it is, every
# onlagged it, mankind; of cbuchover, aupood, and
# which he you ar
# epoch 26
# Epoch 1/1
# 200278/200278 [==============================] - 349s 2ms/step - loss: 1.2979
# --- Generating with seed: " contrary, in
# the so-called cultured classes, the believers "
# ------ temperature: 0.2
#  contrary, in
# the so-called cultured classes, the believers of the strength to the same in the same of the same of the same in the presentiment of himself to subody of the sense of the same of the spirit of the spirit of the same of the soul and soul of the same of the soul is a conduct, and the present and subjection of the strength of the soul is a su

# %%
train_labels[10]

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

# Our vectorized training data
x_train = vectorize_sequences(train_data)
# Our vectorized test data
x_test = vectorize_sequences(test_data)

# %%
def to_one_hot(labels, dimension=46):
    results = np.zeros((len(labels), dimension))
    for i, label in enumerate(labels):
        results[i, label] = 1.
    return results

# Our vectorized training labels
one_hot_train_labels = to_one_hot(train_labels)
# Our vectorized test labels
one_hot_test_labels = to_one_hot(test_labels)

# %%
from keras.utils.np_utils import to_categorical

one_hot_train_labels = to_categorical(train_labels)
one_hot_test_labels = to_categorical(test_labels)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000]
partial_y_train = one_hot_train_labels[1000:]

# %%
history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=20,
                    batch_size=512,
                    validation_data=(x_val, y_val))

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()   # clear figure

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(partial_x_train,
          partial_y_train,
          epochs=8,
          batch_size=512,
          validation_data=(x_val, y_val))
results = model.evaluate(x_test, one_hot_test_labels)

# %%
results

# %%
import copy

test_labels_copy = copy.copy(test_labels)
np.random.shuffle(test_labels_copy)
float(np.sum(np.array(test_labels) == np.array(test_labels_copy))) / len(test_labels)

# %%
predictions = model.predict(x_test)

# %%
predictions[0].shape

# %%
np.sum(predictions[0])

# %%
np.argmax(predictions[0])

# %%
y_train = np.array(train_labels)
y_test = np.array(test_labels)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['acc'])

# %%
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(4, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(partial_x_train,
          partial_y_train,
          epochs=20,
          batch_size=128,
          validation_data=(x_val, y_val))
